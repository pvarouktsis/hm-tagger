# %% [markdown]
# # Wikipedia Dataset
#
# ---
#
# ## Introduction
#
# In the present Jupyter Notebook, we will build from scratch a Wikipedia Dataset to pre-train a machine learning model which acknowledges the subject of a question (e.g. mathematics, physics, etc.).
#
# In order to build such a dataset, we will use the [Outline of Academic Disciplines](https://wikipedia.org/wiki/Outline_of_academic_disciplines) to better classify the Wikipedia articles to approach the tags of 100mentors.
#
# We will achieve this by selecting article links relevant to the subject specified. In other words, we will select the "sub-domains" of academic disciplines as presented in the outline.
#
# Moreover, we will visit each of the selected articles, obtain their introduction text and its links, repeating this process until the desired depth is achieved.
#
# For this reason, we will often refer to an article and its links to other articles as a "node" and its "children nodes", respectively. We can imagine it as traversing a tree structure. In more detail, the further we traverse the tree the weaker the correlation is between the article and the academic discipline it belongs to. However, we will not be concerned with this idea as we will retrieve only the direct "descendants" of the "node".
#
# ## Summary
#
# The dataset contains **12872** reports.
#
# Each report contains:
# - **tag**: the **tag\*** that matches the article
# - **title**: the **title** of the article
# - **text**: the **text\*\*** of the article
#
# The dataset covers **21** of **23 tags**.
#
# **"Career"** and **"Foreign Languages"** do **NOT** match with any domain.
#
# \* with **tag** we mean **100mentors tags**<br>
# \** with **text** we mean the **introduction text** of an article
#
# #### Abbreviations
#
# - **WArt** (Wikipedia Article)
# - **AD** (Academic Discipline)

# %% [markdown]
# ## Build
#
# ---
#
# At first we will import the required packages in order to build the Wikipedia Dataset.

# %%
import re
import sys
import traceback
import time

import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

import pandas as pd
import numpy as np

# set tqdm's bar format
bar_format = '{l_bar}{bar:50}{r_bar}{bar:-10b}'
# set pandas' column width
pd.set_option('max_colwidth', None)

PATH = "data/intros/"

# %% [markdown]
# We will, manually, select the ADs from the "Outline of Academic Desciplines" article that are most relevant to the tags of 100mentors.

# %%
ads = [
    # Humanities
    { 'el': 'h3', 'attr': 'id',    'ad': 'Visual arts',              'tag': 'Visual Arts'                         },
    { 'el': 'h3', 'attr': 'id',    'ad': 'History',                  'tag': 'History'                             },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Languages and literature', 'tag': 'Language and Literature'             },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Philosophy',               'tag': 'Philosophy'                          },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Theology',                 'tag': 'Religion'                            },
    { 'el': 'li', 'attr': 'title', 'ad': 'Film',                     'tag': 'Film'                                },
    { 'el': 'li', 'attr': 'title', 'ad': 'Dance',                    'tag': 'Dance'                               },
    { 'el': 'li', 'attr': 'title', 'ad': 'Theatre',                  'tag': 'Theatre'                             },
    { 'el': 'li', 'attr': 'title', 'ad': 'Music',                    'tag': 'Music'                               },
    # Social Sciences
    { 'el': 'h3', 'attr': 'id',    'ad': 'Anthropology',             'tag': 'Anthropology'                        },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Economics',                'tag': 'Economics'                           },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Geography',                'tag': 'Geography'                           },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Political science',        'tag': 'Global Politics'                     },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Psychology',               'tag': 'Psychology'                          },
    # Natural Sciences
    { 'el': 'h3', 'attr': 'id',    'ad': 'Biology',                  'tag': 'Biology'                             },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Chemistry',                'tag': 'Chemistry'                           },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Physics',                  'tag': 'Physics'                             },
    # Formal Sciences
    { 'el': 'h3', 'attr': 'id',    'ad': 'Computer Science',         'tag': 'Computer Science'                    },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Mathematics',              'tag': 'Mathematics'                         },
    # Applied Sciences
    { 'el': 'h3', 'attr': 'id',    'ad': 'Business',                 'tag': 'Business Management'                 },
    { 'el': 'h3', 'attr': 'id',    'ad': 'Medicine and health',      'tag': 'Sports, Exercise and Health Science' },
    { 'el': 'li', 'attr': 'title', 'ad': 'Physical fitness',         'tag': 'Sports, Exercise and Health Science' },
]

# %% [markdown]
# There are a total of 22 ADs, considering that the "Exercise/Health Science" tag consists of 2 ADs.
#
# Furthermore, we need to implement a function to get a wart.

# %%
def get_wart(url):
    try:
        req = requests.get("https://en.wikipedia.org" + url)
    except requests.exceptions.RequestException as reqex:
        print(f"Unable to get {article_url}: {reqex}")
    else:
        html = req.content
        soup = BeautifulSoup(html, 'html.parser')
        return soup

# %% [markdown]
# We will, additionally, implement a function that finds the "validated" links in an element.

# %%
def get_links(element, validate=None, *args, **kwargs):
    links = []
    for a in element.find_all('a'):
        link = a.attrs.get('href', False)
        if link:
            if validate:
                validated_link = validate(link, *args, **kwargs)
                if validated_link:
                    links.append(validated_link)
                
                continue

                continue
            
            links.append(link)
                
        
    return links

# %% [markdown]
# For that reason, we will implement a function that validates a wart link.

# %%
def validate_wart_link(link):
    # wart's link pattern
    wart_link_pattern = re.compile(r'^(\/wiki\/)[^:]*$')
    
    if not link\
       or not bool(re.match(wart_link_pattern, link))\
       or 'outline' in link.lower(): # 'outline' not in wart link

        return False
    
    hashtag_index = link.find('#')
    if hashtag_index != -1: # remove hashtag from wart link
        return link[:hashtag_index]
    
    return link

# %% [markdown]
# Finally, we will begin to collect the "starting nodes" using the list of ADs we created earlier.

# %%
wart = get_wart('/wiki/Outline_of_academic_disciplines')

starting_warts = []
for ad in ads:
    # find ad's element
    ad_element = wart.find(lambda el: ad['el'] == el.name and ad['ad'] in el.text)

    # find links of ad element
    wart_links = get_links(ad_element, validate_wart_link)
    starting_warts.extend([{'tag': ad['tag'], 'url': wart_link} for wart_link in wart_links])

    # if ad not heading element, continue
    if not bool(re.match(r'h.', ad['el'])):
        continue
    
    # find sibling element
    sibling_element = ad_element\
        .find_next_sibling( lambda tag: (tag.name == 'div' and 'div-col' in tag.attrs['class'])
                            or (tag.name == 'ul') )

    # find links of sibling element
    while (sibling_element and not bool(re.match(r'h.', sibling_element.name))):
        current_wart_links = get_links(sibling_element, validate_wart_link)
        starting_warts.extend([{'tag': ad['tag'], 'url': current_wart_link} for current_wart_link in current_wart_links])
        sibling_element = sibling_element\
            .find_next_sibling( lambda el: re.match(r'h.', el.name)
                                or ( el.name == 'div' and 'div-col' in el.attrs['class']) 
                                or (el.name == 'ul') )

print('length:', len(starting_warts))
[print(starting_wart) for starting_wart in starting_warts]; # colon to hide cell's output
# Out:
# length: 949
# {'tag': 'Visual Arts', 'url': '/wiki/Visual_arts'}
# {'tag': 'Visual Arts', 'url': '/wiki/Fine_arts'}
# {'tag': 'Visual Arts', 'url': '/wiki/Graphic_arts'}
# {'tag': 'Visual Arts', 'url': '/wiki/Drawing'}
# {'tag': 'Visual Arts', 'url': '/wiki/Painting'}
# {'tag': 'Visual Arts', 'url': '/wiki/Photography'}
# {'tag': 'Visual Arts', 'url': '/wiki/Sculpture'}
# {'tag': 'Visual Arts', 'url': '/wiki/Applied_arts'}
# {'tag': 'Visual Arts', 'url': '/wiki/Animation'}
# {'tag': 'Visual Arts', 'url': '/wiki/Calligraphy'}
# {'tag': 'Visual Arts', 'url': '/wiki/Decorative_arts'}
# {'tag': 'Visual Arts', 'url': '/wiki/Mixed_media'}
# {'tag': 'Visual Arts', 'url': '/wiki/Printmaking'}
# {'tag': 'Visual Arts', 'url': '/wiki/Studio_art'}
# {'tag': 'Visual Arts', 'url': '/wiki/Architecture'}
# {'tag': 'Visual Arts', 'url': '/wiki/Interior_architecture'}
# {'tag': 'Visual Arts', 'url': '/wiki/Landscape_architecture'}
# {'tag': 'Visual Arts', 'url': '/wiki/Landscape_design'}
# {'tag': 'Visual Arts', 'url': '/wiki/Landscape_planning'}
# {'tag': 'Visual Arts', 'url': '/wiki/Architectural_analytics'}
# {'tag': 'Visual Arts', 'url': '/wiki/Historic_preservation'}
# {'tag': 'Visual Arts', 'url': '/wiki/Interior_design'}
# {'tag': 'Visual Arts', 'url': '/wiki/Interior_architecture'}
# {'tag': 'Visual Arts', 'url': '/wiki/Technical_drawing'}
# {'tag': 'Visual Arts', 'url': '/wiki/Fashion'}
# {'tag': 'History', 'url': '/wiki/History'}
# {'tag': 'History', 'url': '/wiki/African_history'}
# {'tag': 'History', 'url': '/wiki/American_history'}
# {'tag': 'History', 'url': '/wiki/Ancient_history'}
# {'tag': 'History', 'url': '/wiki/Ancient_Egypt'}
# {'tag': 'History', 'url': '/wiki/Carthage'}
# {'tag': 'History', 'url': '/wiki/Ancient_Greece'}
# {'tag': 'History', 'url': '/wiki/Ancient_Rome'}
# {'tag': 'History', 'url': '/wiki/Assyria'}
# {'tag': 'History', 'url': '/wiki/Bronze_Age'}
# {'tag': 'History', 'url': '/wiki/Historicity_of_the_Bible'}
# {'tag': 'History', 'url': '/wiki/Indus_Valley_Civilisation'}
# {'tag': 'History', 'url': '/wiki/Preclassic_Maya'}
# {'tag': 'History', 'url': '/wiki/History_of_Mesopotamia'}
# {'tag': 'History', 'url': '/wiki/The_Stone_Age'}
# {'tag': 'History', 'url': '/wiki/Yangtze_civilization'}
# {'tag': 'History', 'url': '/wiki/Yellow_River_civilization'}
# {'tag': 'History', 'url': '/wiki/History_of_Asia'}
# {'tag': 'History', 'url': '/wiki/History_of_China'}
# {'tag': 'History', 'url': '/wiki/History_of_India'}
# {'tag': 'History', 'url': '/wiki/History_of_Indonesia'}
# {'tag': 'History', 'url': '/wiki/History_of_Iran'}
# {'tag': 'History', 'url': '/wiki/History_of_Australia'}
# {'tag': 'History', 'url': '/wiki/Ecclesiastical_history_of_the_Catholic_Church'}
# {'tag': 'History', 'url': '/wiki/Economic_history_of_the_world'}
# {'tag': 'History', 'url': '/wiki/Environmental_history'}
# {'tag': 'History', 'url': '/wiki/History_of_Europe'}
# {'tag': 'History', 'url': '/wiki/Intellectual_history'}
# {'tag': 'History', 'url': '/wiki/Jewish_history'}
# {'tag': 'History', 'url': '/wiki/History_of_Latin_America'}
# {'tag': 'History', 'url': '/wiki/Modern_history'}
# {'tag': 'History', 'url': '/wiki/History_of_philosophy'}
# {'tag': 'History', 'url': '/wiki/Ancient_philosophy'}
# {'tag': 'History', 'url': '/wiki/Contemporary_philosophy'}
# {'tag': 'History', 'url': '/wiki/Medieval_philosophy'}
# {'tag': 'History', 'url': '/wiki/Humanism'}
# {'tag': 'History', 'url': '/wiki/Scholasticism'}
# {'tag': 'History', 'url': '/wiki/Modern_philosophy'}
# {'tag': 'History', 'url': '/wiki/History_of_political_thought'}
# {'tag': 'History', 'url': '/wiki/Pre-Columbian_era'}
# {'tag': 'History', 'url': '/wiki/History_of_Russia'}
# {'tag': 'History', 'url': '/wiki/Cultural_history'}
# {'tag': 'History', 'url': '/wiki/History_of_Science'}
# {'tag': 'History', 'url': '/wiki/History_of_Technology'}
# {'tag': 'History', 'url': '/wiki/World_history'}
# {'tag': 'History', 'url': '/wiki/Public_history'}
# {'tag': 'Language and Literature', 'url': '/wiki/Languages'}
# {'tag': 'Language and Literature', 'url': '/wiki/Literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/Linguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Applied_linguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Composition_studies'}
# {'tag': 'Language and Literature', 'url': '/wiki/Computational_linguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Discourse_analysis'}
# {'tag': 'Language and Literature', 'url': '/wiki/English_studies'}
# {'tag': 'Language and Literature', 'url': '/wiki/Etymology'}
# {'tag': 'Language and Literature', 'url': '/wiki/Grammar'}
# {'tag': 'Language and Literature', 'url': '/wiki/Grammatology'}
# {'tag': 'Language and Literature', 'url': '/wiki/Historical_linguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/History_of_linguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Interlinguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Lexicology'}
# {'tag': 'Language and Literature', 'url': '/wiki/Linguistic_typology'}
# {'tag': 'Language and Literature', 'url': '/wiki/Morphology_(linguistics)'}
# {'tag': 'Language and Literature', 'url': '/wiki/Natural_language_processing'}
# {'tag': 'Language and Literature', 'url': '/wiki/Philology'}
# {'tag': 'Language and Literature', 'url': '/wiki/Phonetics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Phonology'}
# {'tag': 'Language and Literature', 'url': '/wiki/Pragmatics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Psycholinguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Rhetoric'}
# {'tag': 'Language and Literature', 'url': '/wiki/Semantics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Semiotics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Sociolinguistics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Syntax'}
# {'tag': 'Language and Literature', 'url': '/wiki/Usage'}
# {'tag': 'Language and Literature', 'url': '/wiki/Word_usage'}
# {'tag': 'Language and Literature', 'url': '/wiki/Comparative_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/Creative_writing'}
# {'tag': 'Language and Literature', 'url': '/wiki/Fiction'}
# {'tag': 'Language and Literature', 'url': '/wiki/Non-fiction'}
# {'tag': 'Language and Literature', 'url': '/wiki/English_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/History_of_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/Ancient_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/Medieval_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/Post-colonial_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/Post-modern_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/Literary_theory'}
# {'tag': 'Language and Literature', 'url': '/wiki/Critical_theory'}
# {'tag': 'Language and Literature', 'url': '/wiki/Literary_criticism'}
# {'tag': 'Language and Literature', 'url': '/wiki/Poetics'}
# {'tag': 'Language and Literature', 'url': '/wiki/Poetry'}
# {'tag': 'Language and Literature', 'url': '/wiki/World_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/African-American_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/American_literature'}
# {'tag': 'Language and Literature', 'url': '/wiki/British_literature'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Aesthetics'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_and_economics'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_education'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_engineering'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_history'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_language'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_law'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_mathematics'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_music'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_psychology'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_religion'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_science'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_biology'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_chemistry'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_physics'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_social_science'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_technology'}
# {'tag': 'Philosophy', 'url': '/wiki/Systems_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Epistemology'}
# {'tag': 'Philosophy', 'url': '/wiki/Theory_of_justification'}
# {'tag': 'Philosophy', 'url': '/wiki/List_of_fallacies'}
# {'tag': 'Philosophy', 'url': '/wiki/Ethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Applied_ethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Animal_rights'}
# {'tag': 'Philosophy', 'url': '/wiki/Bioethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Environmental_ethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Meta-ethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Moral_psychology'}
# {'tag': 'Philosophy', 'url': '/wiki/Descriptive_ethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Value_theory'}
# {'tag': 'Philosophy', 'url': '/wiki/Normative_ethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Virtue_ethics'}
# {'tag': 'Philosophy', 'url': '/wiki/Logic'}
# {'tag': 'Philosophy', 'url': '/wiki/Mathematical_logic'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophical_logic'}
# {'tag': 'Philosophy', 'url': '/wiki/Meta-philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Metaphysics'}
# {'tag': 'Philosophy', 'url': '/wiki/Action_(philosophy)'}
# {'tag': 'Philosophy', 'url': '/wiki/Determinism'}
# {'tag': 'Philosophy', 'url': '/wiki/Free_will'}
# {'tag': 'Philosophy', 'url': '/wiki/Ontology'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_mind'}
# {'tag': 'Philosophy', 'url': '/wiki/Pain_(philosophy)'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_artificial_intelligence'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_perception'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophy_of_space_and_time'}
# {'tag': 'Philosophy', 'url': '/wiki/Teleology'}
# {'tag': 'Philosophy', 'url': '/wiki/Theism'}
# {'tag': 'Philosophy', 'url': '/wiki/Atheism'}
# {'tag': 'Philosophy', 'url': '/wiki/Philosophical_movement'}
# {'tag': 'Philosophy', 'url': '/wiki/African_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Analytic_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Aristotelianism'}
# {'tag': 'Philosophy', 'url': '/wiki/Continental_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Eastern_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Feminist_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Platonism'}
# {'tag': 'Philosophy', 'url': '/wiki/Social_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Political_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Anarchism'}
# {'tag': 'Philosophy', 'url': '/wiki/Feminist_philosophy'}
# {'tag': 'Philosophy', 'url': '/wiki/Libertarianism'}
# {'tag': 'Philosophy', 'url': '/wiki/Marxism'}
# {'tag': 'Religion', 'url': '/wiki/Theology'}
# {'tag': 'Religion', 'url': '/wiki/Biblical_studies'}
# {'tag': 'Religion', 'url': '/wiki/Biblical_Hebrew'}
# {'tag': 'Religion', 'url': '/wiki/Koine_Greek'}
# {'tag': 'Religion', 'url': '/wiki/Aramaic'}
# {'tag': 'Religion', 'url': '/wiki/Religious_studies'}
# {'tag': 'Religion', 'url': '/wiki/Buddhist_philosophy'}
# {'tag': 'Religion', 'url': '/wiki/Pali_language'}
# {'tag': 'Religion', 'url': '/wiki/Christian_theology'}
# {'tag': 'Religion', 'url': '/wiki/Anglican_theology'}
# {'tag': 'Religion', 'url': '/wiki/Baptist_theology'}
# {'tag': 'Religion', 'url': '/wiki/Catholic_theology'}
# {'tag': 'Religion', 'url': '/wiki/Eastern_Orthodox_theology'}
# {'tag': 'Religion', 'url': '/wiki/Protestant_theology'}
# {'tag': 'Religion', 'url': '/wiki/Hindu_theology'}
# {'tag': 'Religion', 'url': '/wiki/Sanskrit_language'}
# {'tag': 'Religion', 'url': '/wiki/Dravidian_studies'}
# {'tag': 'Religion', 'url': '/wiki/Jewish_theology'}
# {'tag': 'Religion', 'url': '/wiki/Muslim_theology'}
# {'tag': 'Religion', 'url': '/wiki/Arabic_language'}
# {'tag': 'Film', 'url': '/wiki/Film_studies'}
# {'tag': 'Film', 'url': '/wiki/Animation'}
# {'tag': 'Film', 'url': '/wiki/Film_criticism'}
# {'tag': 'Film', 'url': '/wiki/Filmmaking'}
# {'tag': 'Film', 'url': '/wiki/Film_theory'}
# {'tag': 'Film', 'url': '/wiki/Live_action'}
# {'tag': 'Dance', 'url': '/wiki/Dance'}
# {'tag': 'Dance', 'url': '/wiki/Choreography'}
# {'tag': 'Dance', 'url': '/wiki/Dance_notation'}
# {'tag': 'Dance', 'url': '/wiki/Ethnochoreology'}
# {'tag': 'Dance', 'url': '/wiki/History_of_dance'}
# {'tag': 'Theatre', 'url': '/wiki/Theatre'}
# {'tag': 'Theatre', 'url': '/wiki/Acting'}
# {'tag': 'Theatre', 'url': '/wiki/Theatre_director'}
# {'tag': 'Theatre', 'url': '/wiki/Dramaturgy'}
# {'tag': 'Theatre', 'url': '/wiki/History_of_theater'}
# {'tag': 'Theatre', 'url': '/wiki/Musical_theatre'}
# {'tag': 'Theatre', 'url': '/wiki/Playwrighting'}
# {'tag': 'Theatre', 'url': '/wiki/Puppetry'}
# {'tag': 'Theatre', 'url': '/wiki/Scenography'}
# {'tag': 'Theatre', 'url': '/wiki/Scenic_design'}
# {'tag': 'Theatre', 'url': '/wiki/Ventriloquism'}
# {'tag': 'Music', 'url': '/wiki/Music'}
# {'tag': 'Music', 'url': '/wiki/Accompaniment'}
# {'tag': 'Music', 'url': '/wiki/Chamber_music'}
# {'tag': 'Music', 'url': '/wiki/Church_music'}
# {'tag': 'Music', 'url': '/wiki/Conducting'}
# {'tag': 'Music', 'url': '/wiki/Choir'}
# {'tag': 'Music', 'url': '/wiki/Orchestra'}
# {'tag': 'Music', 'url': '/wiki/Concert_band'}
# {'tag': 'Music', 'url': '/wiki/Early_music'}
# {'tag': 'Music', 'url': '/wiki/Jazz'}
# {'tag': 'Music', 'url': '/wiki/Musical_composition'}
# {'tag': 'Music', 'url': '/wiki/Music_education'}
# {'tag': 'Music', 'url': '/wiki/Music_history'}
# {'tag': 'Music', 'url': '/wiki/Musicology'}
# {'tag': 'Music', 'url': '/wiki/Music_history'}
# {'tag': 'Music', 'url': '/wiki/Systematic_musicology'}
# {'tag': 'Music', 'url': '/wiki/Ethnomusicology'}
# {'tag': 'Music', 'url': '/wiki/Music_theory'}
# {'tag': 'Music', 'url': '/wiki/Orchestra'}
# {'tag': 'Music', 'url': '/wiki/Organology'}
# {'tag': 'Music', 'url': '/wiki/Organ_(music)'}
# {'tag': 'Music', 'url': '/wiki/Keyboard_instrument'}
# {'tag': 'Music', 'url': '/wiki/Piano'}
# {'tag': 'Music', 'url': '/wiki/String_instrument'}
# {'tag': 'Music', 'url': '/wiki/Harp'}
# {'tag': 'Music', 'url': '/wiki/Oud'}
# {'tag': 'Music', 'url': '/wiki/Guitar'}
# {'tag': 'Music', 'url': '/wiki/Singing'}
# {'tag': 'Music', 'url': '/wiki/Woodwind_instrument'}
# {'tag': 'Music', 'url': '/wiki/Brass_instrument'}
# {'tag': 'Music', 'url': '/wiki/Percussion_instrument'}
# {'tag': 'Music', 'url': '/wiki/Sound_recording_and_reproduction'}
# {'tag': 'Anthropology', 'url': '/wiki/Anthropology'}
# {'tag': 'Anthropology', 'url': '/wiki/Biological_anthropology'}
# {'tag': 'Anthropology', 'url': '/wiki/Linguistic_anthropology'}
# {'tag': 'Anthropology', 'url': '/wiki/Cultural_anthropology'}
# {'tag': 'Anthropology', 'url': '/wiki/Social_anthropology'}
# {'tag': 'Anthropology', 'url': '/wiki/Archaeology'}
# {'tag': 'Economics', 'url': '/wiki/Economics'}
# {'tag': 'Economics', 'url': '/wiki/Agricultural_economics'}
# {'tag': 'Economics', 'url': '/wiki/Anarchist_economics'}
# {'tag': 'Economics', 'url': '/wiki/Applied_economics'}
# {'tag': 'Economics', 'url': '/wiki/Behavioural_economics'}
# {'tag': 'Economics', 'url': '/wiki/Bioeconomics_(biophysical)'}
# {'tag': 'Economics', 'url': '/wiki/Complexity_economics'}
# {'tag': 'Economics', 'url': '/wiki/Computational_economics'}
# {'tag': 'Economics', 'url': '/wiki/Consumer_economics'}
# {'tag': 'Economics', 'url': '/wiki/Development_economics'}
# {'tag': 'Economics', 'url': '/wiki/Ecological_economics'}
# {'tag': 'Economics', 'url': '/wiki/Econometrics'}
# {'tag': 'Economics', 'url': '/wiki/Economic_geography'}
# {'tag': 'Economics', 'url': '/wiki/Economic_sociology'}
# {'tag': 'Economics', 'url': '/wiki/Economic_systems'}
# {'tag': 'Economics', 'url': '/wiki/Education_economics'}
# {'tag': 'Economics', 'url': '/wiki/Energy_economics'}
# {'tag': 'Economics', 'url': '/wiki/Entrepreneurial_economics'}
# {'tag': 'Economics', 'url': '/wiki/Environmental_economics'}
# {'tag': 'Economics', 'url': '/wiki/Evolutionary_economics'}
# {'tag': 'Economics', 'url': '/wiki/Experimental_economics'}
# {'tag': 'Economics', 'url': '/wiki/Feminist_economics'}
# {'tag': 'Economics', 'url': '/wiki/Financial_econometrics'}
# {'tag': 'Economics', 'url': '/wiki/Financial_economics'}
# {'tag': 'Economics', 'url': '/wiki/Green_economics'}
# {'tag': 'Economics', 'url': '/wiki/Economic_growth'}
# {'tag': 'Economics', 'url': '/wiki/Human_development_theory'}
# {'tag': 'Economics', 'url': '/wiki/Industrial_organization'}
# {'tag': 'Economics', 'url': '/wiki/Information_economics'}
# {'tag': 'Economics', 'url': '/wiki/Institutional_economics'}
# {'tag': 'Economics', 'url': '/wiki/International_economics'}
# {'tag': 'Economics', 'url': '/wiki/Islamic_economics'}
# {'tag': 'Economics', 'url': '/wiki/Labor_economics'}
# {'tag': 'Economics', 'url': '/wiki/Law_and_economics'}
# {'tag': 'Economics', 'url': '/wiki/Macroeconomics'}
# {'tag': 'Economics', 'url': '/wiki/Managerial_economics'}
# {'tag': 'Economics', 'url': '/wiki/Marxian_economics'}
# {'tag': 'Economics', 'url': '/wiki/Mathematical_economics'}
# {'tag': 'Economics', 'url': '/wiki/Microeconomics'}
# {'tag': 'Economics', 'url': '/wiki/Monetary_economics'}
# {'tag': 'Economics', 'url': '/wiki/Neuroeconomics'}
# {'tag': 'Economics', 'url': '/wiki/Participatory_economics'}
# {'tag': 'Economics', 'url': '/wiki/Political_economy'}
# {'tag': 'Economics', 'url': '/wiki/Public_economics'}
# {'tag': 'Economics', 'url': '/wiki/Public_finance'}
# {'tag': 'Economics', 'url': '/wiki/Real_estate_economics'}
# {'tag': 'Economics', 'url': '/wiki/Resource_economics'}
# {'tag': 'Economics', 'url': '/wiki/Social_choice_theory'}
# {'tag': 'Economics', 'url': '/wiki/Socialist_economics'}
# {'tag': 'Economics', 'url': '/wiki/Socioeconomics'}
# {'tag': 'Economics', 'url': '/wiki/Transport_economics'}
# {'tag': 'Economics', 'url': '/wiki/Welfare_economics'}
# {'tag': 'Geography', 'url': '/wiki/Geography'}
# {'tag': 'Geography', 'url': '/wiki/Physical_geography'}
# {'tag': 'Geography', 'url': '/wiki/Water_vapour'}
# {'tag': 'Geography', 'url': '/wiki/Biogeography'}
# {'tag': 'Geography', 'url': '/wiki/Climatology'}
# {'tag': 'Geography', 'url': '/wiki/Coastal_geography'}
# {'tag': 'Geography', 'url': '/wiki/Emergency_management'}
# {'tag': 'Geography', 'url': '/wiki/Environmental_geography'}
# {'tag': 'Geography', 'url': '/wiki/Geobiology'}
# {'tag': 'Geography', 'url': '/wiki/Geochemistry'}
# {'tag': 'Geography', 'url': '/wiki/Geology'}
# {'tag': 'Geography', 'url': '/wiki/Geomatics'}
# {'tag': 'Geography', 'url': '/wiki/Geomorphology'}
# {'tag': 'Geography', 'url': '/wiki/Geophysics'}
# {'tag': 'Geography', 'url': '/wiki/Glaciology'}
# {'tag': 'Geography', 'url': '/wiki/Hydrology'}
# {'tag': 'Geography', 'url': '/wiki/Landscape_ecology'}
# {'tag': 'Geography', 'url': '/wiki/Lithology'}
# {'tag': 'Geography', 'url': '/wiki/Meteorology'}
# {'tag': 'Geography', 'url': '/wiki/Mineralogy'}
# {'tag': 'Geography', 'url': '/wiki/Oceanography'}
# {'tag': 'Geography', 'url': '/wiki/Palaeogeography'}
# {'tag': 'Geography', 'url': '/wiki/Palaeontology'}
# {'tag': 'Geography', 'url': '/wiki/Petrology'}
# {'tag': 'Geography', 'url': '/wiki/Quaternary_science'}
# {'tag': 'Geography', 'url': '/wiki/Pedology'}
# {'tag': 'Geography', 'url': '/wiki/Human_geography'}
# {'tag': 'Geography', 'url': '/wiki/Behavioural_geography'}
# {'tag': 'Geography', 'url': '/wiki/Cognitive_geography'}
# {'tag': 'Geography', 'url': '/wiki/Cultural_geography'}
# {'tag': 'Geography', 'url': '/wiki/Development_geography'}
# {'tag': 'Geography', 'url': '/wiki/Economic_geography'}
# {'tag': 'Geography', 'url': '/wiki/Health_geography'}
# {'tag': 'Geography', 'url': '/wiki/Historical_geography'}
# {'tag': 'Geography', 'url': '/wiki/Language_geography'}
# {'tag': 'Geography', 'url': '/wiki/Mathematical_geography'}
# {'tag': 'Geography', 'url': '/wiki/Marketing_geography'}
# {'tag': 'Geography', 'url': '/wiki/Military_geography'}
# {'tag': 'Geography', 'url': '/wiki/Political_geography'}
# {'tag': 'Geography', 'url': '/wiki/Population_geography'}
# {'tag': 'Geography', 'url': '/wiki/Religion_geography'}
# {'tag': 'Geography', 'url': '/wiki/Social_geography'}
# {'tag': 'Geography', 'url': '/wiki/Strategic_geography'}
# {'tag': 'Geography', 'url': '/wiki/Time_geography'}
# {'tag': 'Geography', 'url': '/wiki/Tourism_geography'}
# {'tag': 'Geography', 'url': '/wiki/Transport_geography'}
# {'tag': 'Geography', 'url': '/wiki/Urban_geography'}
# {'tag': 'Geography', 'url': '/wiki/Integrated_geography'}
# {'tag': 'Geography', 'url': '/wiki/Cartography'}
# {'tag': 'Geography', 'url': '/wiki/Celestial_cartography'}
# {'tag': 'Geography', 'url': '/wiki/Planetary_cartography'}
# {'tag': 'Geography', 'url': '/wiki/Topography'}
# {'tag': 'Global Politics', 'url': '/wiki/Political_science'}
# {'tag': 'Global Politics', 'url': '/wiki/Politics_of_the_United_States'}
# {'tag': 'Global Politics', 'url': '/wiki/Politics_of_Canada'}
# {'tag': 'Global Politics', 'url': '/wiki/Civics'}
# {'tag': 'Global Politics', 'url': '/wiki/Comparative_politics'}
# {'tag': 'Global Politics', 'url': '/wiki/European_studies'}
# {'tag': 'Global Politics', 'url': '/wiki/Geopolitics'}
# {'tag': 'Global Politics', 'url': '/wiki/International_relations'}
# {'tag': 'Global Politics', 'url': '/wiki/International_organization'}
# {'tag': 'Global Politics', 'url': '/wiki/Nationalism_studies'}
# {'tag': 'Global Politics', 'url': '/wiki/Peace_and_conflict_studies'}
# {'tag': 'Global Politics', 'url': '/wiki/Policy_studies'}
# {'tag': 'Global Politics', 'url': '/wiki/Theories_of_political_behavior'}
# {'tag': 'Global Politics', 'url': '/wiki/Political_culture'}
# {'tag': 'Global Politics', 'url': '/wiki/Political_economy'}
# {'tag': 'Global Politics', 'url': '/wiki/Political_history'}
# {'tag': 'Global Politics', 'url': '/wiki/Political_philosophy'}
# {'tag': 'Global Politics', 'url': '/wiki/Public_administration'}
# {'tag': 'Global Politics', 'url': '/wiki/Public_law'}
# {'tag': 'Global Politics', 'url': '/wiki/Psephology'}
# {'tag': 'Global Politics', 'url': '/wiki/Social_choice_theory'}
# {'tag': 'Psychology', 'url': '/wiki/Psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Abnormal_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Applied_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Biological_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Clinical_neuropsychology'}
# {'tag': 'Psychology', 'url': '/wiki/Clinical_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Cognitive_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Community_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Comparative_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Conservation_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Consumer_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Counseling_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Criminal_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Cultural_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Asian_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Black_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Developmental_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Differential_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Ecological_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Educational_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Environmental_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Evolutionary_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Experimental_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Group_dynamics'}
# {'tag': 'Psychology', 'url': '/wiki/Journal_of_Family_Psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Feminine_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Forensic_developmental_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Forensic_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Health_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Humanistic_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Indigenous_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Legal_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Mathematical_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Media_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Medical_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Military_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Moral_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Descriptive_ethics'}
# {'tag': 'Psychology', 'url': '/wiki/Music_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Neuropsychology'}
# {'tag': 'Psychology', 'url': '/wiki/Occupational_health_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Occupational_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Industrial_and_organizational_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Parapsychology'}
# {'tag': 'Psychology', 'url': '/wiki/Pediatric_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Pedology_(children_study)'}
# {'tag': 'Psychology', 'url': '/wiki/Personality_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Phenomenology_(psychology)'}
# {'tag': 'Psychology', 'url': '/wiki/Political_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Positive_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Psychoanalysis'}
# {'tag': 'Psychology', 'url': '/wiki/Psychobiology'}
# {'tag': 'Psychology', 'url': '/wiki/Psychology_of_religion'}
# {'tag': 'Psychology', 'url': '/wiki/Psychometrics'}
# {'tag': 'Psychology', 'url': '/wiki/Psychopathology'}
# {'tag': 'Psychology', 'url': '/wiki/Child_psychopathology'}
# {'tag': 'Psychology', 'url': '/wiki/Psychophysics'}
# {'tag': 'Psychology', 'url': '/wiki/Quantitative_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Rehabilitation_Psychology_(journal)'}
# {'tag': 'Psychology', 'url': '/wiki/School_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Social_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Sport_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Traffic_psychology'}
# {'tag': 'Psychology', 'url': '/wiki/Transpersonal_psychology'}
# {'tag': 'Biology', 'url': '/wiki/Biology'}
# {'tag': 'Biology', 'url': '/wiki/Aerobiology'}
# {'tag': 'Biology', 'url': '/wiki/Anatomy'}
# {'tag': 'Biology', 'url': '/wiki/Comparative_anatomy'}
# {'tag': 'Biology', 'url': '/wiki/Human_anatomy'}
# {'tag': 'Biology', 'url': '/wiki/Biochemistry'}
# {'tag': 'Biology', 'url': '/wiki/Bioinformatics'}
# {'tag': 'Biology', 'url': '/wiki/Biophysics'}
# {'tag': 'Biology', 'url': '/wiki/Biotechnology'}
# {'tag': 'Biology', 'url': '/wiki/Botany'}
# {'tag': 'Biology', 'url': '/wiki/Ethnobotany'}
# {'tag': 'Biology', 'url': '/wiki/Phycology'}
# {'tag': 'Biology', 'url': '/wiki/Cell_biology'}
# {'tag': 'Biology', 'url': '/wiki/Chronobiology'}
# {'tag': 'Biology', 'url': '/wiki/Computational_biology'}
# {'tag': 'Biology', 'url': '/wiki/Cryobiology'}
# {'tag': 'Biology', 'url': '/wiki/Developmental_biology'}
# {'tag': 'Biology', 'url': '/wiki/Embryology'}
# {'tag': 'Biology', 'url': '/wiki/Teratology'}
# {'tag': 'Biology', 'url': '/wiki/Ecology'}
# {'tag': 'Biology', 'url': '/wiki/Agroecology'}
# {'tag': 'Biology', 'url': '/wiki/Ethnoecology'}
# {'tag': 'Biology', 'url': '/wiki/Human_ecology'}
# {'tag': 'Biology', 'url': '/wiki/Landscape_ecology'}
# {'tag': 'Biology', 'url': '/wiki/Endocrinology'}
# {'tag': 'Biology', 'url': '/wiki/Epigenetics'}
# {'tag': 'Biology', 'url': '/wiki/Evolutionary_biology'}
# {'tag': 'Biology', 'url': '/wiki/Genetics'}
# {'tag': 'Biology', 'url': '/wiki/Behavioural_genetics'}
# {'tag': 'Biology', 'url': '/wiki/Molecular_genetics'}
# {'tag': 'Biology', 'url': '/wiki/Population_genetics'}
# {'tag': 'Biology', 'url': '/wiki/Histology'}
# {'tag': 'Biology', 'url': '/wiki/Human_biology'}
# {'tag': 'Biology', 'url': '/wiki/Immunology'}
# {'tag': 'Biology', 'url': '/wiki/Limnology'}
# {'tag': 'Biology', 'url': '/wiki/Linnaean_taxonomy'}
# {'tag': 'Biology', 'url': '/wiki/Marine_biology'}
# {'tag': 'Biology', 'url': '/wiki/Mathematical_biology'}
# {'tag': 'Biology', 'url': '/wiki/Microbiology'}
# {'tag': 'Biology', 'url': '/wiki/Bacteriology'}
# {'tag': 'Biology', 'url': '/wiki/Protistology'}
# {'tag': 'Biology', 'url': '/wiki/Molecular_biology'}
# {'tag': 'Biology', 'url': '/wiki/Mycology'}
# {'tag': 'Biology', 'url': '/wiki/Neuroscience'}
# {'tag': 'Biology', 'url': '/wiki/Behavioral_neuroscience'}
# {'tag': 'Biology', 'url': '/wiki/Nutrition'}
# {'tag': 'Biology', 'url': '/wiki/Paleobiology'}
# {'tag': 'Biology', 'url': '/wiki/Paleontology'}
# {'tag': 'Biology', 'url': '/wiki/Parasitology'}
# {'tag': 'Biology', 'url': '/wiki/Pathology'}
# {'tag': 'Biology', 'url': '/wiki/Anatomical_pathology'}
# {'tag': 'Biology', 'url': '/wiki/Clinical_pathology'}
# {'tag': 'Biology', 'url': '/wiki/Dermatopathology'}
# {'tag': 'Biology', 'url': '/wiki/Forensic_pathology'}
# {'tag': 'Biology', 'url': '/wiki/Hematopathology'}
# {'tag': 'Biology', 'url': '/wiki/Histopathology'}
# {'tag': 'Biology', 'url': '/wiki/Molecular_pathology'}
# {'tag': 'Biology', 'url': '/wiki/Surgical_pathology'}
# {'tag': 'Biology', 'url': '/wiki/Physiology'}
# {'tag': 'Biology', 'url': '/wiki/Human_physiology'}
# {'tag': 'Biology', 'url': '/wiki/Exercise_physiology'}
# {'tag': 'Biology', 'url': '/wiki/Structural_Biology'}
# {'tag': 'Biology', 'url': '/wiki/Systematics'}
# {'tag': 'Biology', 'url': '/wiki/Taxonomy_(general)'}
# {'tag': 'Biology', 'url': '/wiki/Systems_biology'}
# {'tag': 'Biology', 'url': '/wiki/Virology'}
# {'tag': 'Biology', 'url': '/wiki/Molecular_virology'}
# {'tag': 'Biology', 'url': '/wiki/Xenobiology'}
# {'tag': 'Biology', 'url': '/wiki/Zoology'}
# {'tag': 'Biology', 'url': '/wiki/Animal_communication'}
# {'tag': 'Biology', 'url': '/wiki/Apiology'}
# {'tag': 'Biology', 'url': '/wiki/Arachnology'}
# {'tag': 'Biology', 'url': '/wiki/Carcinology'}
# {'tag': 'Biology', 'url': '/wiki/Cetology'}
# {'tag': 'Biology', 'url': '/wiki/Entomology'}
# {'tag': 'Biology', 'url': '/wiki/Forensic_entomology'}
# {'tag': 'Biology', 'url': '/wiki/Ethnozoology'}
# {'tag': 'Biology', 'url': '/wiki/Ethology'}
# {'tag': 'Biology', 'url': '/wiki/Helminthology'}
# {'tag': 'Biology', 'url': '/wiki/Herpetology'}
# {'tag': 'Biology', 'url': '/wiki/Ichthyology'}
# {'tag': 'Biology', 'url': '/wiki/Mammalogy'}
# {'tag': 'Biology', 'url': '/wiki/Malacology'}
# {'tag': 'Biology', 'url': '/wiki/Conchology'}
# {'tag': 'Biology', 'url': '/wiki/Myrmecology'}
# {'tag': 'Biology', 'url': '/wiki/Nematology'}
# {'tag': 'Biology', 'url': '/wiki/Neuroethology'}
# {'tag': 'Biology', 'url': '/wiki/Oology'}
# {'tag': 'Biology', 'url': '/wiki/Ornithology'}
# {'tag': 'Biology', 'url': '/wiki/Planktology'}
# {'tag': 'Biology', 'url': '/wiki/Primatology'}
# {'tag': 'Biology', 'url': '/wiki/Zootomy'}
# {'tag': 'Biology', 'url': '/wiki/Zoosemiotics'}
# {'tag': 'Chemistry', 'url': '/wiki/Chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Agrochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Analytical_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Astrochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Atmospheric_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Biochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Chemical_biology'}
# {'tag': 'Chemistry', 'url': '/wiki/Chemical_engineering'}
# {'tag': 'Chemistry', 'url': '/wiki/Cheminformatics'}
# {'tag': 'Chemistry', 'url': '/wiki/Computational_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Cosmochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Electrochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Environmental_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Femtochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Flavor'}
# {'tag': 'Chemistry', 'url': '/wiki/Flow_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Geochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Green_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Histochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Hydrogenation'}
# {'tag': 'Chemistry', 'url': '/wiki/Immunochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Inorganic_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Marine_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Mathematical_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Mechanochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Medicinal_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Molecular_biology'}
# {'tag': 'Chemistry', 'url': '/wiki/Molecular_mechanics'}
# {'tag': 'Chemistry', 'url': '/wiki/Nanotechnology'}
# {'tag': 'Chemistry', 'url': '/wiki/Natural_product_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Neurochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Oenology'}
# {'tag': 'Chemistry', 'url': '/wiki/Organic_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Organometallic_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Petrochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Pharmacology'}
# {'tag': 'Chemistry', 'url': '/wiki/Photochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Physical_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Physical_organic_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Phytochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Polymer_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Quantum_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Radiochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Solid-state_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Sonochemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Supramolecular_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Surface_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Synthetic_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Theoretical_chemistry'}
# {'tag': 'Chemistry', 'url': '/wiki/Thermochemistry'}
# {'tag': 'Physics', 'url': '/wiki/Acoustics'}
# {'tag': 'Physics', 'url': '/wiki/Aerodynamics'}
# {'tag': 'Physics', 'url': '/wiki/Applied_physics'}
# {'tag': 'Physics', 'url': '/wiki/Astrophysics'}
# {'tag': 'Physics', 'url': '/wiki/Atomic,_molecular,_and_optical_physics'}
# {'tag': 'Physics', 'url': '/wiki/Biophysics'}
# {'tag': 'Physics', 'url': '/wiki/Computational_physics'}
# {'tag': 'Physics', 'url': '/wiki/Condensed_matter_physics'}
# {'tag': 'Physics', 'url': '/wiki/Cryogenics'}
# {'tag': 'Physics', 'url': '/wiki/Electricity'}
# {'tag': 'Physics', 'url': '/wiki/Electromagnetism'}
# {'tag': 'Physics', 'url': '/wiki/Elementary_particle_physics'}
# {'tag': 'Physics', 'url': '/wiki/Experimental_physics'}
# {'tag': 'Physics', 'url': '/wiki/Fluid_dynamics'}
# {'tag': 'Physics', 'url': '/wiki/Geophysics'}
# {'tag': 'Physics', 'url': '/wiki/Mathematical_physics'}
# {'tag': 'Physics', 'url': '/wiki/Mechanics'}
# {'tag': 'Physics', 'url': '/wiki/Medical_physics'}
# {'tag': 'Physics', 'url': '/wiki/Molecular_physics'}
# {'tag': 'Physics', 'url': '/wiki/Newton%27s_laws_of_motion'}
# {'tag': 'Physics', 'url': '/wiki/Nuclear_physics'}
# {'tag': 'Physics', 'url': '/wiki/Optics'}
# {'tag': 'Physics', 'url': '/wiki/Plasma_physics'}
# {'tag': 'Physics', 'url': '/wiki/Quantum_physics'}
# {'tag': 'Physics', 'url': '/wiki/Solid_mechanics'}
# {'tag': 'Physics', 'url': '/wiki/Solid_state_physics'}
# {'tag': 'Physics', 'url': '/wiki/Statistical_mechanics'}
# {'tag': 'Physics', 'url': '/wiki/Theoretical_physics'}
# {'tag': 'Physics', 'url': '/wiki/Thermal_physics'}
# {'tag': 'Physics', 'url': '/wiki/Thermodynamics'}
# {'tag': 'Computer Science', 'url': '/wiki/Logic_in_computer_science'}
# {'tag': 'Computer Science', 'url': '/wiki/Formal_methods'}
# {'tag': 'Computer Science', 'url': '/wiki/Formal_verification'}
# {'tag': 'Computer Science', 'url': '/wiki/Logic_programming'}
# {'tag': 'Computer Science', 'url': '/wiki/Multi-valued_logic'}
# {'tag': 'Computer Science', 'url': '/wiki/Fuzzy_logic'}
# {'tag': 'Computer Science', 'url': '/wiki/Formal_semantics_of_programming_languages'}
# {'tag': 'Computer Science', 'url': '/wiki/Type_theory'}
# {'tag': 'Computer Science', 'url': '/wiki/Algorithm'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_geometry'}
# {'tag': 'Computer Science', 'url': '/wiki/Distributed_algorithms'}
# {'tag': 'Computer Science', 'url': '/wiki/Parallel_algorithms'}
# {'tag': 'Computer Science', 'url': '/wiki/Randomized_algorithms'}
# {'tag': 'Computer Science', 'url': '/wiki/Artificial_intelligence'}
# {'tag': 'Computer Science', 'url': '/wiki/Cognitive_science'}
# {'tag': 'Computer Science', 'url': '/wiki/Automated_reasoning'}
# {'tag': 'Computer Science', 'url': '/wiki/Computer_vision'}
# {'tag': 'Computer Science', 'url': '/wiki/Machine_learning'}
# {'tag': 'Computer Science', 'url': '/wiki/Artificial_neural_network'}
# {'tag': 'Computer Science', 'url': '/wiki/Support_vector_machine'}
# {'tag': 'Computer Science', 'url': '/wiki/Natural_language_processing'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_linguistics'}
# {'tag': 'Computer Science', 'url': '/wiki/Expert_systems'}
# {'tag': 'Computer Science', 'url': '/wiki/Robotics'}
# {'tag': 'Computer Science', 'url': '/wiki/Data_structures'}
# {'tag': 'Computer Science', 'url': '/wiki/Computer_architecture'}
# {'tag': 'Computer Science', 'url': '/wiki/Computer_graphics'}
# {'tag': 'Computer Science', 'url': '/wiki/Image_processing'}
# {'tag': 'Computer Science', 'url': '/wiki/Scientific_visualization'}
# {'tag': 'Computer Science', 'url': '/wiki/Computer_networking'}
# {'tag': 'Computer Science', 'url': '/wiki/Cloud_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Information_theory'}
# {'tag': 'Computer Science', 'url': '/wiki/Internet'}
# {'tag': 'Computer Science', 'url': '/wiki/World_Wide_Web'}
# {'tag': 'Computer Science', 'url': '/wiki/Ubiquitous_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Wireless_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Mobile_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Computer_security'}
# {'tag': 'Computer Science', 'url': '/wiki/High_availability'}
# {'tag': 'Computer Science', 'url': '/wiki/Cryptography'}
# {'tag': 'Computer Science', 'url': '/wiki/Fault-tolerant_system'}
# {'tag': 'Computer Science', 'url': '/wiki/Mathematics'}
# {'tag': 'Computer Science', 'url': '/wiki/Natural_science'}
# {'tag': 'Computer Science', 'url': '/wiki/Engineering'}
# {'tag': 'Computer Science', 'url': '/wiki/Medicine'}
# {'tag': 'Computer Science', 'url': '/wiki/Symbolic_computation'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_biology'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_chemistry'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_mathematics'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_neuroscience'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_number_theory'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_physics'}
# {'tag': 'Computer Science', 'url': '/wiki/Computer-aided_engineering'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_fluid_dynamics'}
# {'tag': 'Computer Science', 'url': '/wiki/Finite_element_analysis'}
# {'tag': 'Computer Science', 'url': '/wiki/Numerical_analysis'}
# {'tag': 'Computer Science', 'url': '/wiki/Scientific_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Social_science'}
# {'tag': 'Computer Science', 'url': '/wiki/The_arts'}
# {'tag': 'Computer Science', 'url': '/wiki/Humanities'}
# {'tag': 'Computer Science', 'url': '/wiki/Profession'}
# {'tag': 'Computer Science', 'url': '/wiki/Community_informatics'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_economics'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_finance'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_sociology'}
# {'tag': 'Computer Science', 'url': '/wiki/Digital_humanities'}
# {'tag': 'Computer Science', 'url': '/wiki/History_of_computer_hardware'}
# {'tag': 'Computer Science', 'url': '/wiki/History_of_computer_science'}
# {'tag': 'Computer Science', 'url': '/wiki/Humanistic_informatics'}
# {'tag': 'Computer Science', 'url': '/wiki/Database'}
# {'tag': 'Computer Science', 'url': '/wiki/Distributed_database'}
# {'tag': 'Computer Science', 'url': '/wiki/Object_database'}
# {'tag': 'Computer Science', 'url': '/wiki/Relational_database'}
# {'tag': 'Computer Science', 'url': '/wiki/Data_management'}
# {'tag': 'Computer Science', 'url': '/wiki/Data_mining'}
# {'tag': 'Computer Science', 'url': '/wiki/Information_architecture'}
# {'tag': 'Computer Science', 'url': '/wiki/Information_management'}
# {'tag': 'Computer Science', 'url': '/wiki/Information_retrieval'}
# {'tag': 'Computer Science', 'url': '/wiki/Knowledge_management'}
# {'tag': 'Computer Science', 'url': '/wiki/Multimedia'}
# {'tag': 'Computer Science', 'url': '/wiki/Hypermedia'}
# {'tag': 'Computer Science', 'url': '/wiki/Sound_and_music_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Distributed_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Grid_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Human-computer_interaction'}
# {'tag': 'Computer Science', 'url': '/wiki/Operating_systems'}
# {'tag': 'Computer Science', 'url': '/wiki/Parallel_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/High-performance_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Programming_languages'}
# {'tag': 'Computer Science', 'url': '/wiki/Compilers'}
# {'tag': 'Computer Science', 'url': '/wiki/Programming_paradigms'}
# {'tag': 'Computer Science', 'url': '/wiki/Concurrent_programming_language'}
# {'tag': 'Computer Science', 'url': '/wiki/Functional_programming'}
# {'tag': 'Computer Science', 'url': '/wiki/Imperative_programming'}
# {'tag': 'Computer Science', 'url': '/wiki/Logic_programming'}
# {'tag': 'Computer Science', 'url': '/wiki/Object-oriented_programming'}
# {'tag': 'Computer Science', 'url': '/wiki/Program_semantics'}
# {'tag': 'Computer Science', 'url': '/wiki/Type_theory'}
# {'tag': 'Computer Science', 'url': '/wiki/Quantum_computing'}
# {'tag': 'Computer Science', 'url': '/wiki/Software_engineering'}
# {'tag': 'Computer Science', 'url': '/wiki/Formal_methods'}
# {'tag': 'Computer Science', 'url': '/wiki/Formal_verification'}
# {'tag': 'Computer Science', 'url': '/wiki/Theory_of_computation'}
# {'tag': 'Computer Science', 'url': '/wiki/Automata_theory'}
# {'tag': 'Computer Science', 'url': '/wiki/Formal_languages'}
# {'tag': 'Computer Science', 'url': '/wiki/Computability_theory_(computer_science)'}
# {'tag': 'Computer Science', 'url': '/wiki/Computational_complexity_theory'}
# {'tag': 'Computer Science', 'url': '/wiki/Concurrency_(computer_science)'}
# {'tag': 'Computer Science', 'url': '/wiki/Very-large-scale_integration'}
# {'tag': 'Mathematics', 'url': '/wiki/Mathematical_logic'}
# {'tag': 'Mathematics', 'url': '/wiki/Foundations_of_mathematics'}
# {'tag': 'Mathematics', 'url': '/wiki/Intuitionistic_logic'}
# {'tag': 'Mathematics', 'url': '/wiki/Modal_logic'}
# {'tag': 'Mathematics', 'url': '/wiki/Model_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Proof_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Recursion_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Set_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Associative_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Category_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Topos'}
# {'tag': 'Mathematics', 'url': '/wiki/Differential_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Field_theory_(mathematics)'}
# {'tag': 'Mathematics', 'url': '/wiki/Group_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Group_representation'}
# {'tag': 'Mathematics', 'url': '/wiki/Homological_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/K-theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Lattice_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Order_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Lie_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Linear_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Vector_space'}
# {'tag': 'Mathematics', 'url': '/wiki/Multilinear_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Non-associative_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Representation_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Ring_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Commutative_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Noncommutative_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Universal_algebra'}
# {'tag': 'Mathematics', 'url': '/wiki/Mathematical_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Complex_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Functional_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Operator_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Harmonic_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Fourier_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Non-standard_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Ordinary_differential_equations'}
# {'tag': 'Mathematics', 'url': '/wiki/P-adic_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Partial_differential_equations'}
# {'tag': 'Mathematics', 'url': '/wiki/Real_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Calculus'}
# {'tag': 'Mathematics', 'url': '/wiki/Probability_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Ergodic_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Measure_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Integral_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Stochastic_process'}
# {'tag': 'Mathematics', 'url': '/wiki/Geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Topology'}
# {'tag': 'Mathematics', 'url': '/wiki/Affine_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Algebraic_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Algebraic_topology'}
# {'tag': 'Mathematics', 'url': '/wiki/Convex_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Differential_topology'}
# {'tag': 'Mathematics', 'url': '/wiki/Discrete_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Finite_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Galois_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/General_topology'}
# {'tag': 'Mathematics', 'url': '/wiki/Geometric_topology'}
# {'tag': 'Mathematics', 'url': '/wiki/Integral_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Noncommutative_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Non-Euclidean_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Projective_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Number_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Algebraic_number_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Analytic_number_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Arithmetic_combinatorics'}
# {'tag': 'Mathematics', 'url': '/wiki/Geometric_number_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Approximation_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Combinatorics'}
# {'tag': 'Mathematics', 'url': '/wiki/Coding_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Cryptography'}
# {'tag': 'Mathematics', 'url': '/wiki/Dynamical_systems'}
# {'tag': 'Mathematics', 'url': '/wiki/Chaos_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Fractal_geometry'}
# {'tag': 'Mathematics', 'url': '/wiki/Game_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Graph_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Information_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Mathematical_physics'}
# {'tag': 'Mathematics', 'url': '/wiki/Quantum_field_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Quantum_gravity'}
# {'tag': 'Mathematics', 'url': '/wiki/String_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Quantum_mechanics'}
# {'tag': 'Mathematics', 'url': '/wiki/Statistical_mechanics'}
# {'tag': 'Mathematics', 'url': '/wiki/Numerical_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Operations_research'}
# {'tag': 'Mathematics', 'url': '/wiki/Assignment_problem'}
# {'tag': 'Mathematics', 'url': '/wiki/Decision_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Dynamic_programming'}
# {'tag': 'Mathematics', 'url': '/wiki/Inventory_theory'}
# {'tag': 'Mathematics', 'url': '/wiki/Linear_programming'}
# {'tag': 'Mathematics', 'url': '/wiki/Mathematical_optimization'}
# {'tag': 'Mathematics', 'url': '/wiki/Optimal_maintenance'}
# {'tag': 'Mathematics', 'url': '/wiki/Real_options_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Job_shop_scheduling'}
# {'tag': 'Mathematics', 'url': '/wiki/Stochastic_processes'}
# {'tag': 'Mathematics', 'url': '/wiki/Systems_analysis'}
# {'tag': 'Mathematics', 'url': '/wiki/Statistics'}
# {'tag': 'Mathematics', 'url': '/wiki/Actuarial_science'}
# {'tag': 'Mathematics', 'url': '/wiki/Demography'}
# {'tag': 'Mathematics', 'url': '/wiki/Econometrics'}
# {'tag': 'Mathematics', 'url': '/wiki/Mathematical_statistics'}
# {'tag': 'Mathematics', 'url': '/wiki/Data_visualization'}
# {'tag': 'Mathematics', 'url': '/wiki/Theory_of_computation'}
# {'tag': 'Mathematics', 'url': '/wiki/Computational_complexity_theory'}
# {'tag': 'Business Management', 'url': '/wiki/Business'}
# {'tag': 'Business Management', 'url': '/wiki/Accounting'}
# {'tag': 'Business Management', 'url': '/wiki/Business_management'}
# {'tag': 'Business Management', 'url': '/wiki/Finance'}
# {'tag': 'Business Management', 'url': '/wiki/Marketing'}
# {'tag': 'Business Management', 'url': '/wiki/Operations_management'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Alternative_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Audiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Clinical_laboratory_sciences'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Clinical_pathology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Laboratory_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Clinical_biochemistry'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Cytogenetics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Cytohematology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Cell_biology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Haemostasiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Histology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Clinical_immunology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Clinical_microbiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Molecular_genetics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Parasitology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Clinical_physiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Dentistry'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Dental_hygienist'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Epidemiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Dental_surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Endodontics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Dental_implant'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Oral_and_maxillofacial_surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Orthodontics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Periodontics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Prosthodontics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Dermatology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Emergency_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Epidemiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Geriatrics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Gynaecology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Health_informatics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Clinical_informatics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Hematology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Infectious_disease'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Intensive_care_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Internal_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Cardiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Cardiac_electrophysiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Endocrinology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Gastroenterology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Hepatology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Nephrology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Neurology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Oncology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Pulmonology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Rheumatology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Medical_toxicology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Music_therapy'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Nursing'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Nutrition'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Dietetics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Obstetrics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Occupational_hygiene'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Occupational_therapy'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Occupational_toxicology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Ophthalmology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Neuro-ophthalmology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Optometry'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Otolaryngology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Pathology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Pediatrics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Pharmaceutical_sciences'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Pharmacy'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Physical_fitness'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Aerobics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Kinesiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Personal_fitness_training'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Physical_therapy'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Physiotherapy'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Podiatry'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Preventive_healthcare'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Primary_care'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/General_medical_services'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Psychiatry'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Forensic_psychiatry'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Psychology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Public_health'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Radiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Recreational_therapy'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Physical_medicine_and_rehabilitation'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Respiratory_therapy'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Sleep_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Speech%E2%80%93language_pathology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Sports_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Bariatric_surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Cardiothoracic_surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Neurosurgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Orthoptics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Orthopedic_surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Plastic_surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Trauma_surgery'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Traumatology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Traditional_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Urology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Andrology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Veterinary_medicine'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Physical_fitness'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Aerobics'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Kinesiology'}
# {'tag': 'Sports, Exercise and Health Science', 'url': '/wiki/Personal_fitness_training'}

# %% [markdown]
# We will, lastly, implement a function in which we will, recursively, visit a "node" with its "children nodes", retrieving the introduction of each wart.
#
# We will look for references/links in this section to other warts too.

# %%
def get_data(dataset, visited, current_wart, max_depth, depth=0):
    # if maximum depth exceeded, return
    if depth > max_depth:
        return
    
    # add wart in visited
    visited.add(str(current_wart))

    wart = get_wart(current_wart['url'])
    wart_header = wart.find('h1', {'id': 'firstHeading'})
    wart_content = wart.find('div', {'id': 'bodyContent'})
    wart_inner_content = wart\
        .find('div', {'id': 'mw-content-text'})\
        .find('div', {'class': 'mw-parser-output'})

    # find wart's introduction
    p_list = []
    sibling_element = wart_inner_content.find('p', recursive=False) # strict mode, only on the current DOM depth
    while (sibling_element and not bool(re.match(r'h.', sibling_element.name))):
        p_list.append(sibling_element)
        sibling_element = sibling_element.find_next_sibling(lambda el: el.name == 'p' or bool(re.match(r'h.', el.name)))

    # get wart's introduction links
    for p in p_list:
        for current_wart_link in get_links(p, validate_wart_link):
            temp_wart = {'tag': current_wart['tag'], 'url': current_wart_link}

            # if already visited under the same tag, continue
            if str(temp_wart) in visited:
                continue
            
            # visit wart's introduction links
            get_data(dataset, visited, temp_wart, max_depth, depth+1)
    
    # add wart introduction in dataset 
    text = ' '.join([p.text.strip() for p in p_list])
    dataset.append({'tag': current_wart['tag'], 'title': wart_header.get_text(), 'text': text})

# %% [markdown]
# We will, now, fetch the warts starting from the ones in the ADs list.

# %%
visited = set()
dataset = []
for starting_wart in tqdm(starting_warts, bar_format=bar_format):
    try:
        get_data(dataset, visited, starting_wart, 1)
    except:
        print('Error:', sys.exc_info()[0])
        print('=' * len('Error:' + str(sys.exc_info()[0])))
        print(traceback.format_exc())
# Out:
# 100%|██████████████████████████████████████████████████| 949/949 [1:41:21<00:00,  6.41s/it]

# %% [markdown]
# We can see that we retrieved about **12872** introductions of warts.

# %%
print('length:', len(dataset))
# Out:
# length: 12872

# %% [markdown]
# An example of a report in the dataset can be seen below.

# %%
print(dataset[0])
# Out:
# {'tag': 'Visual Arts', 'title': 'Art', 'text': '  Art is a diverse range of (and products of) human activities involving creative imagination to express technical proficiency, beauty, emotional power, or conceptual ideas.[1][2][3] There is no generally agreed definition of what constitutes art,[4][5][6] and ideas have changed over time. The three classical branches of visual art are painting, sculpture, and architecture.[7] Theatre, dance, and other performing arts, as well as literature, music, film and other media such as interactive media, are included in a broader definition of the arts.[1][8] Until the 17th century, art referred to any skill or mastery and was not differentiated from crafts or sciences. In modern usage after the 17th century, where aesthetic considerations are paramount, the fine arts are separated and distinguished from acquired skills in general, such as the decorative or applied arts. The nature of art and related concepts, such as creativity and interpretation, are explored in a branch of philosophy known as aesthetics.[9] The resulting artworks are studied in the professional fields of art criticism and the history of art.'}

# %% [markdown]
# Lastly, we will convert the dataset to a DataFrame...

# %%
df = pd.DataFrame(dataset)
df.head(3)
# Out:
#            tag     title  \
# 0  Visual Arts       Art
# 1  Visual Arts  Painting
# 2  Visual Arts   Drawing
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      text
# 0                                                                                                                                                                                                                                                                                                                                                                                                                           Art is a diverse range of (and products of) human activities involving creative imagination to express technical proficiency, beauty, emotional power, or conceptual ideas.[1][2][3] There is no generally agreed definition of what constitutes art,[4][5][6] and ideas have changed over time. The three classical branches of visual art are painting, sculpture, and architecture.[7] Theatre, dance, and other performing arts, as well as literature, music, film and other media such as interactive media, are included in a broader definition of the arts.[1][8] Until the 17th century, art referred to any skill or mastery and was not differentiated from crafts or sciences. In modern usage after the 17th century, where aesthetic considerations are paramount, the fine arts are separated and distinguished from acquired skills in general, such as the decorative or applied arts. The nature of art and related concepts, such as creativity and interpretation, are explored in a branch of philosophy known as aesthetics.[9] The resulting artworks are studied in the professional fields of art criticism and the history of art.
# 1                                                                                                            Painting is the practice of applying paint, pigment, color or other medium to a solid surface (called the "matrix" or "support").[1] The medium is commonly applied to the base with a brush, but other implements, such as knives, sponges, and airbrushes, can be used. In art, the term painting describes both the act and the result of the action (the final work is called "a painting"). The support for paintings includes such surfaces as walls, paper, canvas, wood, glass, lacquer, pottery, leaf, copper and concrete, and the painting may incorporate multiple other materials, including sand, clay, paper, plaster, gold leaf, and even whole objects. Painting is an important form in the visual arts, bringing in elements such as drawing, composition, gesture (as in gestural painting), narration (as in narrative art), and abstraction (as in abstract art).[2] Paintings can be naturalistic and representational (as in still life and landscape painting), photographic, abstract, narrative, symbolistic (as in Symbolist art), emotive (as in Expressionism) or political in nature (as in Artivism). A portion of the history of painting in both Eastern and Western art is dominated by religious art. Examples of this kind of painting range from artwork depicting mythological figures on pottery, to Biblical scenes on the Sistine Chapel ceiling, to scenes from the life of Buddha (or other images of Eastern religious origin).
# 2  Drawing is a form of visual art in which an artist uses instruments to mark paper or other two-dimensional surface. Drawing instruments include graphite pencils, pen and ink, various kinds of paints, inked brushes, colored pencils, crayons, charcoal, chalk, pastels, erasers, markers, styluses, and metals (such as silverpoint). Digital drawing is the act of using a computer to draw. Common methods of digital drawing include a stylus or finger on a touchscreen device, stylus- or finger-to-touchpad, or in some cases, a mouse. There are many digital art programs and devices. A drawing instrument releases a small amount of material onto a surface, leaving a visible mark. The most common support for drawing is paper, although other materials, such as cardboard, wood, plastic, leather, canvas, and board, have been used. Temporary drawings may be made on a blackboard or whiteboard. Drawing has been a popular and fundamental means of public expression throughout human history. It is one of the simplest and most efficient means of communicating ideas.[1] The wide availability of drawing instruments makes drawing one of the most common artistic activities. In addition to its more artistic forms, drawing is frequently used in commercial illustration, animation, architecture, engineering, and technical drawing. A quick, freehand drawing, usually not intended as a finished work, is sometimes called a sketch. An artist who practices or works in technical drawing may be called a drafter, draftsman, or draughtsman.[2]

# %% [markdown]
# and extract it to a CSV.

# %%
df.to_csv(PATH + 'temp_intros.csv', index=False, index_label=False)
